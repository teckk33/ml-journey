# %%
import torch
import torch.nn as nn
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
class kmeans:
    def __init__(self, k=3, max_iters=100, tol=1e-4):
        self.k = k
        self.max_iters = max_iters
        self.tol = tol
        self.centroids = None
        self.labels = None
        self.inertia_history = []

    def euc_distance(self, x, centroids):
        diff = x.unsqueeze

# %%
#допишу потом, как столкнусь с к минс в практике. пока что не вижу смысла это все прописывать просто чтобы понять как работает к минс под капотом. теорию я ес че усвоил.
